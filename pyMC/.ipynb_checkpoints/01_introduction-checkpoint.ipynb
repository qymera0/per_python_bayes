# %% [markdown]
# # INTRODUCTORY OVERVIEW OF PYMC

# %% [markdown]
# ## LOAD LIBRARIES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import arviz as az
import pymc as pm

# %% [markdown]
# ## Generating data

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
# Initialize random number generator
seed = 8927
rng = np.random.default_rng(seed)
az.style.use('arviz-darkgrid')

# %%
# True parameters value
alpha, sigma = 1, 1
beta = [1, 2.5]

# %%
# Size of dataset
size = 100

# %%
# Predictors
X1 = np.random.randn(size)
X2 = np.random.randn(size) * 0.2

# %%
# Simulate outcome varible
Y = alpha + beta[0] * X1 + beta[1] * X2 + rng.normal(size = size) * sigma

# %%
# Plot
fig, axes = plt.subplots(1, 2, sharex = True, figsize=(10,4))
axes[0].scatter(X1, Y, alpha=0.6)
axes[1].scatter(X2, Y, alpha=0.6)
axes[0].set_ylabel("Y")
axes[0].set_xlabel("X1")
axes[1].set_xlabel("X2")
# Out:
# Text(0.5, 0, 'X2')

# %% [markdown]
# ## Model specification

# %%
print(f"Running on PyMC v{pm.__version__}")
# Out:
# Running on PyMC v5.6.1

# %%
basicModel = pm.Model()

# %%
with basicModel:
    # Priors for unknow model parameters
    alpha = pm.Normal('alpha', mu = 0, sigma = 10)
    beta = pm.Normal('beta', mu = 0, sigma = 10, shape = 2)
    sigma = pm.HalfNormal('sigma', sigma = 1)

    # Model formula
    mu = alpha + beta[0] * X1 + beta[1] * X2

    # Likelyhood
    Y_obs = pm.Normal('Y_obs', mu = mu, sigma = sigma, observed = Y)

# %% [markdown]
# ## Chains execution

# %%
with basicModel:
    idata = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [alpha, beta, sigma]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:10&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 61 seconds.

# %%
idata.posterior['alpha'].sel(draw = slice(0, 4))
# Out:
# <xarray.DataArray 'alpha' (chain: 4, draw: 5)>
# array([[0.99462135, 1.14836787, 1.11650466, 1.11650466, 1.13729918],
#        [1.11174178, 1.19978043, 1.26078508, 1.30204152, 0.9709788 ],
#        [1.11539656, 1.29524907, 1.07967691, 1.23150359, 1.21710048],
#        [1.15564627, 1.16528312, 1.11242615, 1.21866501, 1.18015321]])
# Coordinates:
#   * chain    (chain) int32 0 1 2 3
#   * draw     (draw) int32 0 1 2 3 4

# %%
# Slice sampling instead od Nuts
with basicModel:
    # Initialize sampler
    step = pm.Slice()

    # Draw 5000 posterior samples
    slice_data = pm.sample(5000, step = step)
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >Slice: [alpha]
# >Slice: [beta]
# >Slice: [sigma]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='24000' class='' max='24000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [24000/24000 00:26&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 5_000 draw iterations (4_000 + 20_000 draws total) took 65 seconds.

# %% [markdown]
# ## Posterior analysis

# %%
az.plot_trace(idata, combined = True);

# %%
az.summary(idata, round_to = 2)
# Out:
#          mean    sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# alpha    1.16  0.10    0.98     1.35       0.00      0.0   6408.04   3100.77
# beta[0]  1.01  0.10    0.83     1.19       0.00      0.0   6245.92   3513.53
# beta[1]  2.72  0.47    1.87     3.63       0.01      0.0   6583.46   3291.24
# sigma    1.01  0.07    0.88     1.15       0.00      0.0   5241.59   3229.24
#
#          r_hat
# alpha      1.0
# beta[0]    1.0
# beta[1]    1.0
# sigma      1.0
