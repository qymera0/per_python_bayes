# %% [markdown]
# # SINGLE STRESS ALT

# %%
import matplotlib.pyplot as plt
from reliability.Datasets import ALT_load2
from reliability.ALT_fitters import Fit_Weibull_Power

# %% [markdown]
# ## Example 1

# %%
Fit_Weibull_Power(
    failures = ALT_load2().failures,
    failure_stress = ALT_load2().failure_stresses,
    right_censored = ALT_load2().right_censored,
    right_censored_stress = ALT_load2().right_censored_stresses,
    use_level_stress = 60               
)

plt.show()
# Out:
# Results from Fit_Weibull_Power (95% CI):
# Analysis method: Maximum Likelihood Estimation (MLE)
# Optimizer: TNC
# Failures / Right censored: 13/5 (27.77778% right censored)
#
# Parameter  Point Estimate  Standard Error  Lower CI    Upper CI
#         a          398597          520329   30858.3 5.14867e+06
#         n         -1.4172        0.244515  -1.89644   -0.937957
#      beta         3.01739        0.716568   1.89448      4.8059
#
#  stress  original alpha  original beta  new alpha  common beta beta change  acceleration factor
#     300         116.174        3.01009    123.017      3.01739      +0.24%               9.7854
#     200         240.182        3.57635    218.534      3.01739     -15.63%              5.50836
#     100          557.42         2.6792    583.631      3.01739     +12.62%              2.06255
#
#  Goodness of fit    Value
#  Log-likelihood -76.8541
#            AICc  161.422
#             BIC  162.379
#
# At the use level stress of 60, the mean life is 1075.21307
